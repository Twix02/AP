# %% [markdown]
# # Tutorial 2 - The Queens & The Art of Branching

# %% [markdown]
# **Important:** You must fully complete Tutorial $i-1$ before starting Tutorial $i$ ($i>1$).
#
# Constraint programming is used to solve highly combinatorial and complex problems.
# In order to master CP, you need to get used to the philosophy behind this approach as well as the different
# techniques used along with it. We will guide you in this process step by step in the upcoming tutorials. We will be using "toy" puzzles/problems only for the purpose of learning different faces of CP. In real life problems, things get messed up easily and require decision and policy makes to agree opon the problem at hand.. (Trust us, we've been there..)
#
# In this tutorial, we use the N-Queens problem, one of oldest and classical problems solved efficiently by CP, as a case study.

# %% [markdown]
# ## 1. The N-Queens problem

# %% [markdown]
# You are given an N-by-N chessboard, and your goal is to place N chess queens on it so that no two queens threaten each other:
#
# <div class="row" style="margin-top: 10px">
#     <div class="col-md-5">
#         <img src="display/images/empty-chessboard.png" style="margin-right: 0; width: 160px;" />
#     </div>
#     <div class="col-md-2" style="display: table">
#         <i class="fa fa-arrow-right" style="display: table-cell; font-size: 50px;
#         margin: auto; text-align: center; vertical-align: middle; height: 150px"></i>
#     </div>
#     <div class="col-md-5">
#         <img src="display/images/nqueens8-chessboard.png" style="margin-left: 0; width: 160px;" />
#     </div>
# </div>
#
# Formally, a solution to the N-queens problem requires that no two queens share the same row, column or diagnoal.

# %% [markdown]
# ### 1.1. Model without global constraints

# %% [markdown]
# **Exercice**: Create a function `decomposition_model(N)` that models the problem using only binary inequality constrants (no global constraint) and returns an instance of `CpoModel` for the n-queens problem with `N` queens.

# %%
#Make sure that you update the variable os.environ['PATH'] in the config/__init__.py file
from config import setup
setup()
from docplex.cp.model import *

# %%
pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: matplotlib in /home/nourdine/.local/lib/python3.7/site-packages (3.5.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/insa/anaconda/envs/cplex/lib/python3.7/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/nourdine/.local/lib/python3.7/site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in /home/nourdine/.local/lib/python3.7/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in /home/nourdine/.local/lib/python3.7/site-packages (from matplotlib) (9.3.0)
# Requirement already satisfied: packaging>=20.0 in /home/nourdine/.local/lib/python3.7/site-packages (from matplotlib) (22.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/nourdine/.local/lib/python3.7/site-packages (from matplotlib) (4.38.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/nourdine/.local/lib/python3.7/site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: numpy>=1.17 in /home/nourdine/.local/lib/python3.7/site-packages (from matplotlib) (1.21.6)
# Requirement already satisfied: typing-extensions in /home/nourdine/.local/lib/python3.7/site-packages (from kiwisolver>=1.0.1->matplotlib) (4.4.0)
# Requirement already satisfied: six>=1.5 in /usr/local/insa/anaconda/envs/cplex/lib/python3.7/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
def decomposition_model(N):
    model = CpoModel(name = 'The N-Queens problem')
    X = model.integer_var_list(N, 0, N-1, "x")
    for i in range(N):
        for j in range(N):
            if i != j:
                model.add(X[i] != X[j])
                model.add(X[j] - X[i] != j - i)
                model.add(X[j] - X[i] != i - j)
    return model

# %% [markdown]
# **Exercice:** Test your function by solving the n-queens problem for small values of $N$ ($N < 20$).
#
# <div class="alert alert-block alert-info">
#
# Use the `display.n_queens` function in order to display a solution for the n-queens problem. This function can take a list of `int` corresponding to the column of the queens in order to display them.
#
# </div>

# %%
import display
# %matplotlib inline

N = 10

model = decomposition_model(N)
solution = model.solve(LogVerbosity = 'Quiet')
queens = [solution.get_value(f"x_{i}") for i in range(N)]
display.n_queens(queens)

# %% [markdown]
# **Question**: How many solutions are there for $N = 3,~\ldots,~10$?
#
# **Note:** To answer this question, you must force the solver to use a depth first strategy using  `CpoModel.start_search(SearchType="DepthFirst")`.

# %%
solutions = model.start_search(SearchType="DepthFirst")
for sol in solutions :
    print(sol)
          
          
#N=3 : Pas de solution
#N=4 : 2 solutions
#N=5 : 10 solutions
#N=6 : 4 solutions
#N=7 : 40 solutions
#N=8 : 92 solutions
#N=9 : 352 solutions
#N=10: 724 solutions
# Out:
#  ! ----------------------------------------------------------------------------
#  ! Satisfiability problem - 10 variables, 270 constraints
#  ! Workers              = 1
#  ! Presolve             = Off
#  ! SearchType           = DepthFirst
#  ! Initial process time : 0.00s (0.00s extraction + 0.00s propagation)
#  !  . Log search space  : 33.2 (before), 33.2 (after)
#  !  . Memory usage      : 339.4 kB (before), 339.4 kB (after)
#  ! Using sequential search.
#  ! ----------------------------------------------------------------------------
#  !               Branches  Non-fixed            Branch decision
#  *                     42  0.00s                  3 != x_4
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                     51  0.00s                  5  = x_9
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                     97  0.00s                  4 != x_8
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                    121  0.00s                  4  = x_5
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                    139  0.00s                  3  = x_9
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                    189  0.00s                  1 != x_7
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                    216  0.00s                  1 != x_4
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                    238  0.00s                  5  = x_5
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                    246  0.00s                  1 != x_5
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                    261  0.00s                  1 != x_7
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                    344  0.00s                  7  = x_4
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                    358  0.00s                  7  = x_4
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                    368  0.00s                  8  = x_0
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                    369  0.00s                  8 != x_0
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                    390  0.00s                  4  = x_9
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                    397  0.00s                  7 != x_0
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                    406  0.00s                  4 != x_4
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                    424  0.00s                  1 != x_4
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                    453  0.00s                  6 != x_6
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                    467  0.00s                  2 != x_6
#  ! Time = 0.00s, Average fail depth = 6, Memory usage = 776.5 kB
#  !               Branches  Non-fixed            Branch decision
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                    496  0.00s                  2  = x_5
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                    556  0.00s                  1 != x_6
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                    576  0.00s                  6 != x_6
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                    581  0.00s                  2  = x_9
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                    582  0.00s                  2 != x_9
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                    585  0.00s                  2  = x_5
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                    608  0.00s                  8  = x_7
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                    609  0.00s                  8 != x_7
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                    619  0.00s                  6  = x_0
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                    627  0.00s                  2  = x_5
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                    715  0.00s                  7  = x_6
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                    737  0.00s                  1  = x_7
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                    752  0.00s                  1 != x_7
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                    771  0.00s                  4  = x_8
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                    824  0.00s                  4  = x_8
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                    830  0.00s                  1 != x_9
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                    885  0.00s                  7  = x_6
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                    891  0.00s                  2 != x_7
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                    895  0.00s                  2  = x_6
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                    905  0.00s                  7  = x_4
#  ! Time = 0.00s, Average fail depth = 6, Memory usage = 776.5 kB
#  !               Branches  Non-fixed            Branch decision
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                    910  0.00s                  4  = x_8
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                    916  0.00s                  3 != x_7
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                    979  0.00s                  2  = x_6
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#                      1000          2              3 != x_0
#  *                   1001  0.00s                  3  = x_8
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   1055  0.00s                  4  = x_8
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   1079  0.00s                  5  = x_4
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   1081  0.00s                  8  = x_4
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   1100  0.00s                  2  = x_8
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   1103  0.00s                  1 != x_9
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   1117  0.01s                  6  = x_4
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   1120  0.01s                  6  = x_7
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   1152  0.01s                  3  = x_4
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   1163  0.01s                  4 != x_8
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   1178  0.01s                  1  = x_4
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   1180  0.01s                  2  = x_8
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   1209  0.01s                  5  = x_9
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   1252  0.01s                  7  = x_7
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   1295  0.01s                  6  = x_4
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   1321  0.01s                  1 != x_7
#  ! Time = 0.01s, Average fail depth = 6, Memory usage = 776.8 kB
#  !               Branches  Non-fixed            Branch decision
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   1343  0.01s                  6  = x_4
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   1351  0.01s                  1 != x_6
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   1373  0.01s                  4  = x_8
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   1404  0.01s                  2 != x_9
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   1459  0.01s                  5  = x_4
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   1529  0.01s                  3  = x_4
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   1666  0.01s                  6  = x_5
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   1667  0.01s                  6 != x_5
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   1670  0.01s                  6 != x_9
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   1680  0.01s                  5 != x_9
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   1682  0.01s                  7  = x_0
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   1689  0.01s                  5 != x_7
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   1695  0.01s                  8  = x_7
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   1711  0.01s                  7  = x_6
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   1725  0.01s                  2 != x_0
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   1738  0.01s                  8  = x_6
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   1755  0.01s                  2 != x_5
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   1758  0.01s                  2 != x_0
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   1770  0.01s                  0 != x_7
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   1771  0.01s                  4 != x_6
#  ! Time = 0.01s, Average fail depth = 6, Memory usage = 776.8 kB
#  !               Branches  Non-fixed            Branch decision
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   1791  0.01s                  7  = x_4
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   1847  0.01s                  5  = x_0
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   1853  0.01s                  8  = x_4
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   1860  0.01s                  6  = x_0
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   1861  0.01s                  6 != x_0
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   1867  0.01s                  2 != x_8
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   1916  0.01s                  0 != x_4
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   1945  0.01s                  0 != x_0
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#                      2000          2        F     2  = x_8
#  *                   2010  0.01s                  7  = x_7
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   2011  0.01s                  7 != x_7
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   2020  0.01s                  3  = x_5
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   2055  0.01s                  0  = x_4
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   2061  0.01s                  2 != x_8
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   2062  0.01s                  7 != x_0
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   2066  0.01s                  2  = x_7
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   2090  0.01s                  8  = x_8
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   2105  0.01s                  0  = x_0
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   2106  0.01s                  0 != x_0
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   2132  0.01s                  7  = x_4
#  ! Time = 0.01s, Average fail depth = 6, Memory usage = 776.8 kB
#  !               Branches  Non-fixed            Branch decision
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   2144  0.01s                  0 != x_5
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   2194  0.01s                  7  = x_7
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   2200  0.01s                  4 != x_7
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   2201  0.01s                  5 != x_5
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   2241  0.01s                  3  = x_9
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   2248  0.01s                  7  = x_7
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   2265  0.01s                  3  = x_7
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   2271  0.01s                  0 != x_7
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   2276  0.01s                  8  = x_7
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   2277  0.01s                  8 != x_7
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   2289  0.01s                  0 != x_7
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   2297  0.01s                  5  = x_8
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   2303  0.01s                  3 != x_9
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   2306  0.01s                  2 != x_9
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   2310  0.01s                  8  = x_7
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   2316  0.01s                  4  = x_9
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   2358  0.01s                  0 != x_5
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   2364  0.01s                  5  = x_0
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   2366  0.01s                  8  = x_0
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   2369  0.01s                  4 != x_9
#  ! Time = 0.01s, Average fail depth = 6, Memory usage = 776.8 kB
#  !               Branches  Non-fixed            Branch decision
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   2372  0.01s                  5  = x_0
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   2386  0.01s                  5 != x_9
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   2410  0.01s                  0  = x_9
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   2411  0.01s                  0 != x_9
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   2424  0.01s                  6  = x_6
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   2425  0.01s                  6 != x_6
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   2436  0.01s                  0 != x_4
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   2441  0.01s                  2 != x_6
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   2472  0.01s                  0  = x_5
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   2491  0.01s                  2 != x_4
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   2538  0.01s                  6  = x_6
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   2567  0.01s                  7  = x_6
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   2577  0.01s                  6  = x_6
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   2604  0.01s                  7  = x_6
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   2608  0.01s                  7 != x_0
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   2633  0.01s                  0  = x_8
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   2647  0.01s                  0  = x_8
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   2668  0.01s                  0  = x_0
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   2669  0.01s                  0 != x_0
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   2679  0.01s                  0  = x_6
#  ! Time = 0.01s, Average fail depth = 6, Memory usage = 776.8 kB
#  !               Branches  Non-fixed            Branch decision
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   2689  0.01s                  5  = x_9
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   2692  0.01s                  7 != x_9
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   2758  0.01s                  5  = x_0
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   2788  0.01s                  5  = x_8
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   2789  0.01s                  5 != x_8
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   2794  0.01s                  3 != x_8
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   2798  0.01s                  7  = x_6
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   2803  0.01s                  0  = x_9
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   2824  0.01s                  4  = x_4
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   2833  0.01s                  3 != x_5
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   2849  0.01s                  3 != x_7
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   2905  0.02s                  2  = x_7
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   2914  0.02s                  3  = x_6
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   2920  0.02s                  2 != x_6
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   2936  0.02s                  6 != x_9
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   2949  0.02s                  2 != x_8
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   2952  0.02s                  3  = x_8
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   2957  0.02s                  4  = x_9
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   2988  0.02s                  3  = x_7
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#                      3000          2        F     0 != x_3
#  ! Time = 0.02s, Average fail depth = 6, Memory usage = 776.8 kB
#  !               Branches  Non-fixed            Branch decision
#  *                   3005  0.02s                  6  = x_3
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   3033  0.03s                  0 != x_5
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   3056  0.03s                  3 != x_4
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   3098  0.03s                  8 != x_3
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   3105  0.03s                  0 != x_5
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   3109  0.03s                  5 != x_3
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   3124  0.03s                  8  = x_4
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   3125  0.03s                  8 != x_4
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   3129  0.03s                  7  = x_1
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   3140  0.03s                  1  = x_5
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   3142  0.03s                  0 != x_9
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   3155  0.03s                  6  = x_7
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   3157  0.03s                  6  = x_1
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   3181  0.03s                  0 != x_5
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   3186  0.03s                  6 != x_1
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   3218  0.03s                  7 != x_8
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   3226  0.03s                  7  = x_1
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   3239  0.03s                  0 != x_9
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   3246  0.03s                  4  = x_9
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   3247  0.03s                  4 != x_9
#  ! Time = 0.03s, Average fail depth = 6, Memory usage = 776.8 kB
#  !               Branches  Non-fixed            Branch decision
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   3250  0.03s                  0  = x_5
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   3254  0.03s                  4  = x_7
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   3259  0.03s                  5 != x_6
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   3264  0.03s                  1 != x_5
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   3274  0.03s                  4  = x_8
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   3288  0.03s                  1  = x_7
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   3295  0.03s                  1  = x_7
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   3300  0.03s                  7 != x_6
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   3305  0.03s                  6  = x_5
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   3350  0.03s                  6 != x_8
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   3353  0.03s                  6 != x_7
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   3354  0.03s                  0 != x_3
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   3359  0.03s                  3  = x_6
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   3384  0.03s                  0  = x_8
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   3385  0.03s                  0 != x_8
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   3405  0.03s                  7  = x_1
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   3420  0.03s                  3  = x_7
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   3437  0.03s                  3  = x_5
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   3451  0.03s                  1  = x_9
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   3456  0.03s                  8  = x_4
#  ! Time = 0.03s, Average fail depth = 6, Memory usage = 776.8 kB
#  !               Branches  Non-fixed            Branch decision
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   3469  0.03s                  3 != x_8
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   3472  0.03s                  3  = x_4
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   3482  0.03s                  1  = x_8
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   3488  0.03s                  0  = x_3
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   3505  0.03s                  4  = x_9
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   3511  0.03s                  1  = x_4
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   3526  0.03s                  3 != x_4
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   3530  0.03s                  1 != x_4
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   3584  0.03s                  8  = x_5
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   3636  0.03s                  8 != x_6
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   3643  0.03s                  0 != x_8
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   3651  0.03s                  0  = x_8
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   3679  0.03s                  3  = x_6
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   3697  0.03s                  8  = x_3
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   3732  0.03s                  1  = x_8
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   3733  0.03s                  1 != x_8
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   3745  0.03s                  6  = x_4
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   3787  0.03s                  4  = x_7
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   3808  0.03s                  1 != x_5
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   3826  0.03s                  3 != x_6
#  ! Time = 0.03s, Average fail depth = 6, Memory usage = 776.8 kB
#  !               Branches  Non-fixed            Branch decision
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   3840  0.03s                  7  = x_4
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   3845  0.03s                  4 != x_6
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   3849  0.03s                  4  = x_7
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   3863  0.03s                  1 != x_9
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   3888  0.03s                  4 != x_6
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   3891  0.03s                  0  = x_9
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   3904  0.03s                  3 != x_9
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   3915  0.03s                  4 != x_7
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   3961  0.03s                  7  = x_6
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   3962  0.03s                  7 != x_6
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   3974  0.03s                  6  = x_9
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   3975  0.03s                  6 != x_9
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#                      4000          2        F     0  = x_6
#  *                   4007  0.03s                  1  = x_5
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   4026  0.03s                  6  = x_7
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   4053  0.03s                  6  = x_9
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   4087  0.03s                  6 != x_8
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   4097  0.03s                  7  = x_9
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   4105  0.03s                  7  = x_1
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   4122  0.03s                  5  = x_8
#  ! Time = 0.03s, Average fail depth = 6, Memory usage = 776.8 kB
#  !               Branches  Non-fixed            Branch decision
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   4143  0.04s                  4  = x_0
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   4144  0.04s                  4 != x_0
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   4154  0.04s                  5  = x_6
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   4171  0.04s                  0 != x_1
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   4180  0.04s                  0  = x_0
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   4181  0.04s                  0 != x_0
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   4182  0.04s                  2 != x_9
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   4184  0.04s                  0  = x_8
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   4185  0.04s                  0 != x_8
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   4194  0.04s                  7 != x_8
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   4209  0.04s                  5  = x_3
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   4248  0.04s                  4  = x_8
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   4267  0.04s                  6 != x_0
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   4268  0.04s                  0 != x_4
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   4284  0.04s                  0 != x_1
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   4308  0.04s                  0 != x_9
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   4310  0.04s                  0  = x_0
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   4311  0.04s                  0 != x_0
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   4353  0.05s                  8  = x_4
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   4361  0.05s                  4  = x_9
#  ! Time = 0.05s, Average fail depth = 6, Memory usage = 776.8 kB
#  !               Branches  Non-fixed            Branch decision
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   4369  0.05s                  8  = x_0
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   4411  0.05s                  1 != x_8
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   4450  0.05s                  8  = x_6
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   4471  0.05s                  0  = x_3
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   4525  0.05s                  8 != x_3
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   4545  0.05s                  8  = x_4
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   4552  0.05s                  8  = x_3
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   4604  0.05s                  2 != x_0
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   4623  0.05s                  2  = x_9
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   4624  0.05s                  2 != x_9
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   4678  0.05s                  4  = x_0
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   4682  0.05s                  0  = x_3
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   4700  0.05s                  5 != x_6
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   4728  0.05s                  5 != x_6
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   4731  0.05s                  6 != x_0
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   4735  0.05s                  5  = x_8
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   4775  0.05s                  2 != x_4
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   4777  0.05s                  8  = x_9
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   4778  0.05s                  8 != x_9
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   4786  0.05s                  1 != x_8
# ...
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                  10554  0.10s                  0  = x_7
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                  10556  0.10s                  2  = x_7
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                  10605  0.10s                  1  = x_5
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                  10635  0.10s                  7  = x_4
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                  10676  0.10s                  4  = x_8
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                  10685  0.10s                  3  = x_9
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                  10686  0.10s                  3 != x_9
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                  10691  0.10s                  1  = x_4
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                  10695  0.10s                  1  = x_8
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                  10721  0.10s                  0  = x_6
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                  10730  0.11s                  1 != x_6
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                  10734  0.11s                  0  = x_4
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                  10742  0.11s                  1 != x_1
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                  10752  0.11s                  4  = x_0
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                  10756  0.11s                  1 != x_4
#  ! Time = 0.11s, Average fail depth = 5, Memory usage = 776.8 kB
#  !               Branches  Non-fixed            Branch decision
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                  10767  0.11s                  7  = x_8
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                  10797  0.11s                  4  = x_0
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                  10800  0.12s                  0  = x_0
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                  10817  0.12s                  0  = x_0
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                  10828  0.12s                  5  = x_0
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                  10832  0.12s                  3 != x_8
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                  10837  0.12s                  5 != x_6
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                  10843  0.12s                  5  = x_6
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                  10849  0.12s                  1 != x_0
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                  10870  0.12s                  3  = x_6
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                  10915  0.12s                  2 != x_7
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#                     11000          2        F     2  = x_0
#  *                  11056  0.12s                  6  = x_9
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                  11095  0.12s                  5 != x_9
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                  11144  0.12s                  3  = x_4
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                  11145  0.12s                  3 != x_4
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                  11155  0.12s                  2  = x_6
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                  11166  0.12s                  0 != x_9
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                  11214  0.12s                  0 != x_7
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                  11250  0.12s                  2 != x_7
#  ! Time = 0.12s, Average fail depth = 5, Memory usage = 776.8 kB
#  !               Branches  Non-fixed            Branch decision
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                  11259  0.12s                  3  = x_4
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                  11268  0.12s                  0  = x_7
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                  11283  0.12s                  4  = x_9
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                  11311  0.12s                  0 != x_8
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                  11331  0.12s                  0  = x_9
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                  11333  0.12s                  1 != x_4
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                  11345  0.12s                  0  = x_7
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                  11347  0.12s                  3  = x_9
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                  11366  0.12s                  1  = x_4
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                  11367  0.12s                  1 != x_4
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                  11392  0.12s                  4 != x_8
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                  11458  0.12s                  1 != x_8
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                  11482  0.12s                  1 != x_6
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                  11544  0.12s                  5  = x_7
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                  11553  0.12s                  1 != x_8
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                  11555  0.12s                  1  = x_7
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                  11567  0.12s                  4 != x_6
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                  11576  0.12s                  5  = x_9
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                  11581  0.12s                  0 != x_6
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                  11634  0.12s                  7  = x_9
#  ! Time = 0.12s, Average fail depth = 5, Memory usage = 776.8 kB
#  !               Branches  Non-fixed            Branch decision
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                  11642  0.12s                  2 != x_8
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                  11702  0.12s                  6  = x_6
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                  11722  0.12s                  5  = x_4
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                  11740  0.12s                  6 != x_7
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                  11761  0.12s                  0 != x_6
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                  11848  0.12s                  3 != x_6
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                  11853  0.12s                  1 != x_0
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                  11861  0.12s                  0  = x_0
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                  11862  0.12s                  0 != x_0
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                  11866  0.12s                  6  = x_7
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                  11867  0.12s                  6 != x_7
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                  11890  0.12s                  0  = x_8
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                  11891  0.12s                  0 != x_8
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                  11911  0.12s                  0 != x_0
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                  11969  0.12s                  2  = x_7
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                  12000  0.13s                  5 != x_4
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#                     12000          2        F        -
#  *                  12020  0.13s                  1  = x_8
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                  12021  0.13s                  1 != x_8
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                  12052  0.13s                  1  = x_4
#  ! Time = 0.13s, Average fail depth = 5, Memory usage = 776.8 kB
#  !               Branches  Non-fixed            Branch decision
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                  12057  0.13s                  7  = x_5
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                  12068  0.13s                  0 != x_9
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                  12089  0.13s                  3  = x_9
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                  12102  0.13s                  2 != x_8
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                  12104  0.13s                  7  = x_8
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                  12124  0.13s                  3 != x_6
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                  12195  0.13s                  5  = x_7
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                  12205  0.13s                  4 != x_8
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                  12231  0.13s                  6  = x_9
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                  12280  0.13s                  6  = x_7
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                  12285  0.13s                  6  = x_7
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                  12316  0.13s                  6 != x_8
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                  12332  0.13s                  1 != x_5
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                  12351  0.13s                  6 != x_6
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                  12406  0.13s                  1 != x_9
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                  12414  0.13s                  3  = x_4
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  ! ----------------------------------------------------------------------------
#  ! Search completed, 724 solutions found.
#  ! ----------------------------------------------------------------------------
#  ! Number of branches     : 12450
#  ! Number of fails        : 5502
#  ! Total memory usage     : 849.7 kB (809.5 kB CP Optimizer + 40.2 kB Concert)
#  ! Time spent in solve    : 0.13s (0.13s engine + 0.00s extraction)
#  ! Search speed (br. / s) : 88928.6
#  ! ----------------------------------------------------------------------------

# %% [markdown]
# ### 1.2. Model with global constraints

# %% [markdown]
# **Exercice:** Create a function `global_constraint_model(N)` that models and returns an instance of `CpoModel` for the n-queens problem with `N` queens, using **only** and exaclty 3 global constraints.

# %%
def global_constraint_model(N):
    model = CpoModel(name = 'The N-Queens problem')
    X = model.integer_var_list(N, 0, N-1, "x")
    
    model.add(all_diff(X))
    model.add(all_diff([X[i]+i for i in range(N)]))
    model.add(all_diff([X[i]-i for i in range(N)]))

    
    return model

# %% [markdown]
# **Exercice:** Test your function by solving the n-queens problem for small values of $N$ ($N < 20$).

# %%
import display
# %matplotlib inline

N = 10

model = global_constraint_model(N)
solution = model.solve(LogVerbosity = 'Quiet')
queens = [solution.get_value(f"x_{i}") for i in range(N)]
display.n_queens(queens)

# %% [markdown]
# **Question**: How many solutions are there for $N = 3,~\ldots,~10$?
#
# **Important:** You should obtain the same number as the previous model!

# %%
solutions = model.start_search(SearchType="DepthFirst")
for sol in solutions :
    print(sol)
# Out:
#  ! ----------------------------------------------------------------------------
#  ! Satisfiability problem - 10 variables, 3 constraints
#  ! Workers              = 1
#  ! Presolve             = Off
#  ! SearchType           = DepthFirst
#  ! Initial process time : 0.00s (0.00s extraction + 0.00s propagation)
#  !  . Log search space  : 33.2 (before), 33.2 (after)
#  !  . Memory usage      : 299.1 kB (before), 299.1 kB (after)
#  ! Using sequential search.
#  ! ----------------------------------------------------------------------------
#  !               Branches  Non-fixed            Branch decision
#  *                     29  0.00s                  8 != x_6
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                    129  0.00s                  1 != x_9
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                    142  0.00s                  2 != x_8
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                    152  0.00s                  1 != x_4
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                    173  0.00s                  1  = x_4
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                    176  0.00s                  1 != x_8
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                    224  0.00s                  2  = x_8
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                    225  0.00s                  2 != x_8
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                    244  0.01s                  4 != x_9
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                    245  0.01s                  1 != x_4
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                    286  0.01s                  2  = x_8
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                    314  0.01s                  4  = x_9
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                    333  0.01s                  3 != x_8
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                    373  0.01s                  1 != x_4
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                    394  0.01s                  3  = x_3
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                    395  0.01s                  3 != x_3
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                    407  0.01s                  8 != x_9
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                    418  0.01s                  3  = x_8
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                    439  0.01s                  1  = x_6
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                    463  0.01s                  6 != x_6
#  ! Time = 0.01s, Average fail depth = 6, Memory usage = 514.2 kB
#  !               Branches  Non-fixed            Branch decision
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                    484  0.01s                  6  = x_4
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                    506  0.01s                  2  = x_8
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                    531  0.01s                  3  = x_8
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                    539  0.01s                  1 != x_4
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                    560  0.01s                  5  = x_3
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                    614  0.02s                  7 != x_8
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                    640  0.02s                  2  = x_6
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                    652  0.02s                  1  = x_5
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                    659  0.02s                  2  = x_9
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                    667  0.02s                  2 != x_9
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                    673  0.02s                  6  = x_4
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                    675  0.02s                  3  = x_6
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                    678  0.02s                  3  = x_4
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                    705  0.02s                  1  = x_7
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                    793  0.02s                  7 != x_7
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                    807  0.02s                  7  = x_6
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                    813  0.02s                  3 != x_7
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                    825  0.02s                  2  = x_7
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                    837  0.02s                  4 != x_4
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                    839  0.02s                  8  = x_6
#  ! Time = 0.02s, Average fail depth = 6, Memory usage = 514.2 kB
#  !               Branches  Non-fixed            Branch decision
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                    841  0.02s                  4  = x_8
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                    842  0.02s                  4 != x_8
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                    857  0.02s                  1  = x_8
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                    860  0.02s                  1  = x_4
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                    909  0.02s                  1 != x_7
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                    944  0.02s                  8  = x_5
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                    951  0.02s                  1  = x_4
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#                      1000          2              2 != x_6
#  *                   1008  0.02s                  1 != x_9
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   1040  0.02s                  2  = x_9
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   1041  0.02s                  2 != x_9
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   1062  0.02s                  2  = x_6
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   1110  0.02s                  4  = x_8
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   1159  0.03s                  4 != x_8
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   1166  0.03s                  1 != x_5
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   1181  0.03s                  7  = x_4
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   1209  0.03s                  1  = x_9
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   1210  0.03s                  1 != x_9
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   1230  0.03s                  5  = x_8
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   1250  0.03s                  1  = x_9
#  ! Time = 0.03s, Average fail depth = 6, Memory usage = 514.5 kB
#  !               Branches  Non-fixed            Branch decision
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   1276  0.03s                  2 != x_7
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   1323  0.03s                  4  = x_3
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   1343  0.03s                  1 != x_5
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   1372  0.03s                  2 != x_6
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   1376  0.03s                  1 != x_5
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   1386  0.03s                  1  = x_5
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   1400  0.03s                  8  = x_7
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   1401  0.03s                  8 != x_7
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   1406  0.03s                  6 != x_4
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   1421  0.03s                  6 != x_4
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   1431  0.03s                  7  = x_4
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   1434  0.03s                  8  = x_7
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   1445  0.03s                  0  = x_4
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   1460  0.03s                  2 != x_9
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   1469  0.03s                  6  = x_1
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   1477  0.03s                  2  = x_8
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   1486  0.03s                  2 != x_7
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   1489  0.03s                  4  = x_1
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   1490  0.03s                  4 != x_1
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   1495  0.03s                  4  = x_7
#  ! Time = 0.03s, Average fail depth = 6, Memory usage = 514.5 kB
#  !               Branches  Non-fixed            Branch decision
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   1514  0.03s                  2  = x_8
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   1532  0.03s                  5 != x_5
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   1535  0.03s                  8  = x_4
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   1540  0.03s                  0  = x_5
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   1542  0.03s                  0  = x_9
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   1549  0.03s                  2  = x_9
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   1611  0.03s                  0 != x_6
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   1612  0.03s                  3 != x_8
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   1661  0.03s                  7  = x_4
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   1665  0.03s                  5 != x_7
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   1675  0.03s                  0 != x_8
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   1705  0.03s                  0  = x_4
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   1723  0.03s                  2  = x_7
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   1725  0.03s                  3  = x_6
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   1730  0.03s                  0 != x_0
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   1741  0.03s                  3  = x_6
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   1751  0.03s                  2 != x_4
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   1758  0.03s                  3 != x_7
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   1778  0.03s                  0 != x_5
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   1790  0.03s                  3  = x_9
#  ! Time = 0.03s, Average fail depth = 6, Memory usage = 514.5 kB
#  !               Branches  Non-fixed            Branch decision
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   1843  0.03s                  4 != x_4
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   1860  0.03s                  4  = x_4
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   1861  0.03s                  4 != x_4
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   1875  0.03s                  3  = x_9
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   1882  0.04s                  7 != x_6
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   1886  0.04s                  2 != x_0
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   1895  0.04s                  0  = x_5
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   1908  0.04s                  3  = x_7
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   1911  0.04s                  2  = x_5
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   1922  0.04s                  8  = x_7
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   1923  0.04s                  8 != x_7
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   1929  0.04s                  3 != x_9
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   1932  0.04s                  2 != x_9
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   1935  0.04s                  2  = x_4
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   1943  0.04s                  2 != x_5
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   1953  0.04s                  5 != x_9
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   1987  0.04s                  5 != x_8
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#                      2000          2        F     4  = x_8
#  *                   2014  0.04s                  5  = x_0
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   2022  0.04s                  2  = x_7
#  ! Time = 0.04s, Average fail depth = 6, Memory usage = 514.5 kB
#  !               Branches  Non-fixed            Branch decision
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   2029  0.04s                  5  = x_0
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   2030  0.04s                  5 != x_0
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   2036  0.04s                  0  = x_9
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   2037  0.04s                  0 != x_9
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   2052  0.04s                  5  = x_8
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   2059  0.04s                  5  = x_8
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   2068  0.04s                  0 != x_4
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   2074  0.04s                  0 != x_6
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   2094  0.04s                  4 != x_8
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   2139  0.04s                  2 != x_4
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   2163  0.04s                  7 != x_7
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   2205  0.04s                  3  = x_7
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   2210  0.04s                  3  = x_1
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   2218  0.04s                  0 != x_7
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   2227  0.04s                  0  = x_5
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   2255  0.04s                  3  = x_1
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   2257  0.04s                  4  = x_1
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   2272  0.04s                  7  = x_7
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   2281  0.04s                  0  = x_6
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   2282  0.04s                  0 != x_6
#  ! Time = 0.04s, Average fail depth = 6, Memory usage = 514.5 kB
#  !               Branches  Non-fixed            Branch decision
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   2295  0.04s                  5  = x_9
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   2296  0.04s                  5 != x_9
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   2345  0.04s                  0 != x_8
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   2356  0.04s                  2 != x_7
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   2366  0.04s                  7 != x_0
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   2369  0.04s                  3 != x_6
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   2384  0.04s                  2  = x_9
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   2385  0.04s                  2 != x_9
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   2395  0.04s                  4  = x_6
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   2409  0.04s                  2 != x_5
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   2416  0.04s                  3  = x_6
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   2468  0.05s                  0  = x_8
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   2494  0.05s                  0  = x_6
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   2495  0.05s                  0 != x_6
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   2508  0.05s                  2  = x_0
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   2510  0.05s                  3  = x_5
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   2514  0.05s                  2 != x_9
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   2536  0.05s                  2 != x_8
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   2552  0.05s                  4  = x_8
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   2570  0.05s                  1 != x_8
#  ! Time = 0.05s, Average fail depth = 6, Memory usage = 514.5 kB
#  !               Branches  Non-fixed            Branch decision
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   2575  0.05s                  4 != x_6
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   2577  0.05s                  1  = x_5
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   2578  0.05s                  1 != x_5
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   2581  0.05s                  1  = x_5
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   2586  0.05s                  1  = x_6
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   2611  0.05s                  3  = x_7
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   2616  0.05s                  3  = x_4
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   2624  0.05s                  6 != x_1
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   2626  0.05s                  7  = x_6
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   2635  0.05s                  6  = x_0
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   2648  0.05s                  1  = x_6
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   2657  0.05s                  1  = x_8
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   2686  0.05s                  5  = x_0
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   2687  0.05s                  5 != x_0
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   2688  0.05s                  8 != x_6
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   2724  0.05s                  4  = x_1
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   2742  0.05s                  1 != x_4
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   2759  0.05s                  5  = x_0
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   2766  0.05s                  5 != x_0
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   2769  0.05s                  1 != x_9
#  ! Time = 0.05s, Average fail depth = 6, Memory usage = 514.5 kB
#  !               Branches  Non-fixed            Branch decision
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   2774  0.05s                  3  = x_7
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   2780  0.05s                  3 != x_7
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   2788  0.05s                  0  = x_9
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   2789  0.05s                  0 != x_9
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   2799  0.05s                  5 != x_1
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   2805  0.05s                  0 != x_1
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   2814  0.05s                  1  = x_5
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   2826  0.05s                  3  = x_7
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   2827  0.05s                  3 != x_7
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   2837  0.05s                  3 != x_6
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   2846  0.05s                  1  = x_4
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   2879  0.05s                  8 != x_4
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   2880  0.05s                  0 != x_6
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   2915  0.05s                  6 != x_1
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   2922  0.05s                  1  = x_4
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   2942  0.05s                  1  = x_8
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   2943  0.05s                  1 != x_8
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   2952  0.05s                  4 != x_5
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   2991  0.05s                  1  = x_9
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   2998  0.05s                  4 != x_8
#  ! Time = 0.05s, Average fail depth = 6, Memory usage = 514.5 kB
#  !               Branches  Non-fixed            Branch decision
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#                      3000          2              3  = x_5
#  *                   3004  0.05s                  1  = x_0
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   3025  0.05s                  1 != x_5
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   3035  0.05s                  4 != x_9
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   3043  0.05s                  0 != x_5
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   3057  0.05s                  4  = x_7
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   3077  0.05s                  3 != x_6
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   3078  0.05s                  8 != x_0
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   3085  0.05s                  3  = x_4
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   3095  0.05s                  3 != x_9
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   3110  0.05s                  4  = x_9
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   3131  0.05s                  3 != x_9
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   3132  0.05s                  0 != x_7
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   3146  0.05s                  0  = x_9
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   3170  0.06s                  3 != x_7
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   3188  0.06s                  6  = x_9
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   3194  0.06s                  1  = x_5
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   3211  0.06s                  0  = x_6
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   3223  0.06s                  3  = x_7
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   3253  0.06s                  4 != x_8
#  ! Time = 0.06s, Average fail depth = 6, Memory usage = 514.5 kB
#  !               Branches  Non-fixed            Branch decision
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   3270  0.06s                  3  = x_6
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   3273  0.06s                  1  = x_8
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   3280  0.06s                  3  = x_8
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   3293  0.06s                  6 != x_4
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   3315  0.06s                  0 != x_9
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   3329  0.06s                  3 != x_4
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   3334  0.06s                  4 != x_5
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   3336  0.06s                  0  = x_5
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   3337  0.06s                  0 != x_5
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   3346  0.06s                  0 != x_9
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   3352  0.06s                  4  = x_7
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   3372  0.06s                  0  = x_8
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   3374  0.06s                  0  = x_5
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   3388  0.06s                  5 != x_8
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   3391  0.06s                  1  = x_4
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   3411  0.06s                  1  = x_8
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   3414  0.06s                  2  = x_5
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   3437  0.06s                  4  = x_8
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   3439  0.06s                  1 != x_7
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   3461  0.06s                  1  = x_5
#  ! Time = 0.06s, Average fail depth = 6, Memory usage = 514.5 kB
#  !               Branches  Non-fixed            Branch decision
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   3466  0.06s                  2 != x_7
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   3491  0.06s                  2  = x_9
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   3492  0.06s                  2 != x_9
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   3502  0.06s                  4  = x_9
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   3563  0.06s                  8 != x_9
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   3583  0.06s                  6  = x_3
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   3637  0.06s                  0 != x_7
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   3673  0.06s                  1 != x_6
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   3722  0.06s                  0  = x_9
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   3740  0.06s                  0  = x_3
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   3744  0.06s                  1  = x_6
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   3749  0.06s                  1  = x_1
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   3750  0.06s                  1 != x_1
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   3763  0.06s                  7  = x_1
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   3764  0.06s                  7 != x_1
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   3773  0.06s                  0  = x_3
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   3776  0.06s                  0 != x_9
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   3782  0.06s                  1 != x_1
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   3802  0.06s                  5  = x_9
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   3803  0.06s                  5 != x_9
#  ! Time = 0.06s, Average fail depth = 6, Memory usage = 514.5 kB
#  !               Branches  Non-fixed            Branch decision
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   3813  0.06s                  0  = x_3
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   3832  0.06s                  0  = x_3
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   3861  0.06s                  0  = x_7
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   3881  0.06s                  1  = x_9
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   3894  0.06s                  2 != x_5
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   3903  0.06s                  2  = x_5
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   3939  0.06s                  0  = x_7
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   3949  0.06s                  2 != x_5
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   3963  0.06s                  4  = x_4
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   3974  0.06s                  5 != x_6
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   3979  0.06s                  0  = x_4
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#                      4000          2        F     1 != x_8
#  *                   4003  0.06s                  1 != x_8
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   4009  0.06s                  2  = x_5
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   4021  0.06s                  5 != x_7
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   4029  0.06s                  2 != x_8
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   4043  0.06s                  1  = x_3
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   4044  0.06s                  1 != x_3
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   4052  0.06s                  2  = x_6
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   4099  0.06s                  6 != x_8
# ...
#  *                   9042  0.10s                  1 != x_7
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   9062  0.10s                  1  = x_7
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   9067  0.10s                  0 != x_0
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   9071  0.10s                  1  = x_0
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   9078  0.10s                  1  = x_4
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   9083  0.10s                  0  = x_5
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   9084  0.10s                  0 != x_5
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   9113  0.10s                  5  = x_9
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   9130  0.10s                  2  = x_7
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   9139  0.10s                  0 != x_8
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   9141  0.10s                  0  = x_5
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   9148  0.10s                  2 != x_7
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   9153  0.10s                  0  = x_8
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   9155  0.10s                  0  = x_0
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   9163  0.10s                  4 != x_7
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   9170  0.10s                  4 != x_9
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   9197  0.10s                  0 != x_0
#  ! Time = 0.10s, Average fail depth = 6, Memory usage = 514.5 kB
#  !               Branches  Non-fixed            Branch decision
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   9212  0.10s                  4  = x_5
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   9220  0.10s                  4  = x_0
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   9224  0.10s                  2  = x_0
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   9235  0.10s                  0  = x_6
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   9245  0.10s                  3 != x_9
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   9246  0.10s                  0 != x_5
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   9248  0.10s                  0  = x_6
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   9260  0.11s                  0  = x_5
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   9272  0.11s                  3 != x_1
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   9295  0.11s                  6 != x_6
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   9327  0.11s                  2  = x_4
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   9360  0.11s                  5  = x_9
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   9388  0.11s                  3 != x_1
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   9390  0.11s                  3  = x_1
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   9398  0.11s                  2  = x_4
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   9411  0.12s                  1 != x_9
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   9443  0.12s                  2  = x_0
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   9457  0.12s                  2 != x_0
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   9458  0.12s                  0 != x_3
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   9463  0.12s                  7 != x_9
#  ! Time = 0.12s, Average fail depth = 5, Memory usage = 514.5 kB
#  !               Branches  Non-fixed            Branch decision
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   9468  0.12s                  0 != x_3
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   9471  0.12s                  0 != x_7
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   9478  0.12s                  0 != x_1
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   9483  0.12s                  6  = x_7
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   9486  0.12s                  0  = x_7
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   9524  0.12s                  4 != x_3
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   9529  0.12s                  6 != x_7
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   9620  0.12s                  5 != x_3
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   9625  0.12s                  1  = x_7
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   9641  0.12s                  7  = x_6
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   9653  0.12s                  4  = x_8
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   9666  0.12s                  6  = x_6
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   9698  0.12s                  4  = x_1
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   9723  0.12s                  6  = x_9
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   9804  0.12s                  1  = x_1
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   9826  0.12s                  3  = x_9
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   9831  0.12s                  4 != x_9
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   9847  0.12s                  0  = x_7
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   9857  0.12s                  0  = x_7
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   9870  0.12s                  1 != x_8
#  ! Time = 0.12s, Average fail depth = 5, Memory usage = 514.5 kB
#  !               Branches  Non-fixed            Branch decision
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   9885  0.12s                  4  = x_0
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   9888  0.12s                  1  = x_0
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   9894  0.12s                  5  = x_8
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   9900  0.12s                  1  = x_1
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   9904  0.12s                  1  = x_8
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   9905  0.12s                  1 != x_8
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   9933  0.12s                  4 != x_1
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   9949  0.12s                  4 != x_1
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   9953  0.12s                  0  = x_9
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   9961  0.12s                  1  = x_1
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   9980  0.12s                  5  = x_9
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   9987  0.12s                  1 != x_8
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                   9991  0.12s                  3  = x_3
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#                     10000          2              3  = x_4
#  *                  10018  0.12s                  2 != x_4
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                  10032  0.12s                  1 != x_3
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                  10034  0.12s                  1  = x_3
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                  10038  0.13s                  4  = x_8
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                  10043  0.13s                  2  = x_4
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                  10058  0.13s                  1  = x_3
#  ! Time = 0.13s, Average fail depth = 5, Memory usage = 514.5 kB
#  !               Branches  Non-fixed            Branch decision
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                  10059  0.13s                  1 != x_3
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                  10074  0.13s                  1  = x_0
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                  10075  0.13s                  1 != x_0
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                  10077  0.13s                  0  = x_0
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                  10105  0.13s                  2  = x_1
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                  10106  0.13s                  2 != x_1
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                  10109  0.13s                  1  = x_4
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                  10118  0.13s                  1  = x_4
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                  10119  0.13s                  1 != x_4
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                  10120  0.13s                  3 != x_3
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                  10147  0.13s                  4 != x_0
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                  10150  0.13s                  2 != x_3
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                  10152  0.13s                  0  = x_6
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  *                  10170  0.13s                  3  = x_4
# (model: The N-Queens problem, solve: Feasible, search: SearchOngoing, solution: (objs: None, gaps: None))
#  ! ----------------------------------------------------------------------------
#  ! Search completed, 724 solutions found.
#  ! ----------------------------------------------------------------------------
#  ! Number of branches     : 10180
#  ! Number of fails        : 4367
#  ! Total memory usage     : 555.4 kB (515.2 kB CP Optimizer + 40.2 kB Concert)
#  ! Time spent in solve    : 0.13s (0.13s engine + 0.00s extraction)
#  ! Search speed (br. / s) : 78307.7
#  ! ----------------------------------------------------------------------------

# %% [markdown]
# ## 2. Comparison of the two models

# %% [markdown]
# We will compare the two models properly.
#
# **Exercice:** Consider the `run(model, params)` function that we used in the first tutorial and paste it here.

# %%
def run(model, params):
    solution = model.solve(
        TimeLimit = params.TimeLimit, 
        LogVerbosity = params.LogVerbosity,
        LogPeriod = params.LogPeriod,
    )
    infos = solution.get_infos()
    return (infos["NumberOfChoicePoints"], infos["TotalTime"], infos["SearchStatus"])

# %% [markdown]
# ### 2.1. Basic comparison
#
# To compare the two models, we will fix the time limit to 5 seconds, i.e. `TimeLimit=5`, while keeping all the other parameters to their default values.

# %% [markdown]
# **Exercice:** Compare the two models for $N \in \{200, 400, 600, .., 2000 \}$.
#
# <div class="alert alert-block alert-info">
#
# By *comparing* we mean plotting the runtime **and** the number of decisions made by the solver for each model as a function of $n$
#
# </div>

# %%
from docplex.cp.parameters import CpoParameters

params = CpoParameters(TimeLimit = 5, LogVerbosity = 'Quiet')

n_list = list(range(200, 2001, 200))
results_decomposition = []
results_global_constraint = []
for i in n_list:
    print("running for n = " + str(i))
    results_decomposition.append(run(decomposition_model(i), params))
    results_global_constraint.append(run(global_constraint_model(i), params))
# Out:
# running for n = 200
# running for n = 400

# %%
import matplotlib.pyplot as plt

x_axis = n_list
plt.xlabel('model size (n)')
plt.plot(x_axis, [i[0] for i in results_decomposition], "b", label='choice points decomposition')
plt.plot(x_axis, [i[0] for i in results_global_constraint], "r", label='choice points global_contraint')
plt.legend()
plt.title("choice points per model size (n)")
plt.show()

plt.xlabel('model size (n)')
plt.plot(x_axis, [i[1] for i in results_decomposition], "b", label='execution time decomposition')
plt.plot(x_axis, [i[1] for i in results_global_constraint], "r", label='execution time global_contraint')
plt.legend()
plt.title("execution time per model size (n)")
plt.show()

# %% [markdown]
# **Question:** What do you observe? Why?

# %% [markdown]
# ### 2.2. Branching strategies
#
#
# **Important:** Before you start this part, please ask one of your supervisors to check on your work.
#
# A CP solver is, at the end of the day, a backtracking solver. At each node, it applies filtering (called also propagation or pruning), then make a decision about the next node to explore. This decision is a pure heuristic choice, that is, it could be a wrong decision, it is only based on intuition.
#
# In CP, a decision is, most of the times, of the type: choose an unassigned variable $x$, choose a value $v$ from the current domain of $x$, and assign $v$ to $x$. These steps require a variable heuristic and a value heuristic. This is what we call branching strategy.
#
# Branching strategies can be generic (strategies that can be used for any problem), or specific (designed for the problem at hand). In CPOptimizer, there are a number of genereic strategies offered. This concerns both variable and value heuristics.
#
# For example, if $L$ is the list of decision variables, then by declaring a search_phase as follows:
#
# ```python
# SearchPhase= model.search_phase(L,
#                                 varchooser=model.select_smallest(model.domain_size()),
#                                 valuechooser=model.select_random_value())
#
# model.add_search_phase(SearchPhase)
# ```
#
# The variable heuristic here is the one that picks the variable $x$ with the smallest domain size, and assigns a random value from its domain to it.
#
#
# Read about the different search strategies here:
# http://ibmdecisionoptimization.github.io/docplex-doc/cp/docplex.cp.modeler.py.html#search-phases
#
#
# We want to evaluate different strategies:
# - For variable evaluators, we will use
#  - `domain_size()`
#  - `var_impact()`
#  - `var_local_impact()`
#  - `var_index()`
#
# - For value evaluators, we will use
#  - `value_impact()`
#  - `value_index()`
#
# As for the selectors we will use :
# - `select_smallest()`
# - `select_largest()`
#
# **Question:** How many strategies are we going to evaluate?

# %% [markdown]
# **Question:** In addition to the above strategies, we will use also a pure random selection for variables and values. How can we use such a branching heuristic?

# %% [markdown]
# Using the global constraints model, run the different strategies (**all of them, and pure random**) for different values of $N$. Make sure you choose a good value of $N$ that can assess your claims of evaluation. Feel free to use any reasnable time limit.
#
# <div class="alert alert-block alert-danger">
#
# **Important:** For this exercice, you must set the `SearchType` to `DepthFirst` using `SearchType="DepthFirst"` when calling `run`.
#
# We will investigate deeply this choice in the next tutorial. But at this stage you should trust us and include it in the solver's parameters.
#
# </div>
#
# **Exercice:** Present the results (rutime + number of nodes) via a table first then using plots.

# %% [markdown]
# # Plots

# %% [markdown]
# # Compare value chooser

# %% [markdown]
# ## var chooser = select smallest

# %% [markdown]
# ## varchooser = select largest

# %% [markdown]
# # Compare var chooser

# %% [markdown]
# ## Value chooser = smallest value impact

# %% [markdown]
# ## Value chooser = smallest value index

# %% [markdown]
# ## Value chooser = largest value impact

# %% [markdown]
# ## Value chooser = larget value index

# %% [markdown]
# ## Random select

# %% [markdown]
# **Question:** Is this what you expect? Is the choice of the branching strategy important? Justify.

# %% [markdown]
# On attendait plus de variations et moins de timeout : presque toutes les stratégies ont un timeout après n=50

# %% [markdown]
# **Question:** What is more important, the variable ordering or the value ordering choice? Justify.

# %% [markdown]
# Pour un value chooser donné, le choix du var chooser impacte plus les résultats. Alors que sur les plots on remarque que pour un var chooser donné, le value chooser ne change rien aux résultats.

# %% [markdown]
# **Question:** What is the best variable ordering choice? Justify.

# %% [markdown]
# Le meilleur semble être le smallest domain size : il a le moins de timeout, le moins de noeuds, et le plus de solutions feasible (les autres ont trop de unknown)

# %% [markdown]
# **Question:** What is the best value ordering choice? Justify.

# %% [markdown]
# Pas de différences observées

# %% [markdown]
# **Question:** What is a good branching overall? Any thoughts why this is the case? Justify.

# %% [markdown]
# Le random est étonnement plutôt bon dans notre cas

# %% [markdown]
# **Question:** Did you observe an opposite behaviour of heuristics betwen the runtime and the number of nodes?
# For instance, is there a strategy that is faster than others to solve the problem but requires a larger number of nodes?
# And conversely, is there a heuristic that is slow to solve the problem than others but uses less nodes?
# If you observe this, why is this happening?

# %% [markdown]
# ## 3. Conclusion
#
# **Question:** What did you learn today?

# %% [markdown]
# <div class="alert alert-block alert-danger"></div>
